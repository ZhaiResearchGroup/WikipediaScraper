# %%
import os
import pandas as pd

# %%
data_dir = 'wiki_data/'
out_csv_path = 'documents.csv'
urls_path = '../wikipedia-biography-dataset/wikipedia-biography-dataset/train/train.url'
titles_path = '../wikipedia-biography-dataset/wikipedia-biography-dataset/train/train.title'
sidebars_path = '../wikipedia-biography-dataset/wikipedia-biography-dataset/train/train.box'

# %%
def parse_document(document_lines):
    start = 0
    while start < len(document_lines) and document_lines[start] != "Contents\n":
        start += 1

    doc = []
    for i in range(start, len(document_lines)):
        if document_lines[i][0] == "^":
            continue

        line_length = len(document_lines[i].split(" "))
        if "References" == document_lines[i][:len("References")] and line_length < 2:
            break

        if line_length > 10:
            doc.append(document_lines[i])

    return ' '.join(doc)

# %%
HEADERS_TO_IGNORE = ["See also", "References", "Bibliography", "External links"]

def parse_content_headers(article_lines):
    index = get_contents_index(article_lines) + 1
    
    headers = []
    
    while True:
        line = article_lines[index]
        if line[0].isnumeric():
            header = " ".join(line.split(" ")[1:]).strip()
            if header not in HEADERS_TO_IGNORE:
                headers.append(header)
        elif line[0] != "\n":
            break
        
        index += 1
    
    return headers

# %%
def get_contents_index(article_lines):
    for i in range(len(article_lines)):
        if article_lines[i] == 'Contents\n':
            return i
    
    return -1

def parse_summary(article_lines):
    index = get_contents_index(article_lines)
    
    while(len(article_lines[index].split(" "))) < 8 and index >= 0:
        index -= 1
    
    summary_indices = []
    summary_indices.append(index)
    
    summary = []
    while len(article_lines[index].split(" ")) > 8 and index >= 0:
        summary.insert(0, article_lines[index].strip())
        index -= 1
        
    summary_indices.append(index)
        
    return ' '.join(summary), summary_indices[::-1]

# %%
sidebar_for_testing = open(sidebars_path, 'r').readlines()

# %%
fieldnames = {}
for i in range(len(sidebar_for_testing)):
    for fieldname in ' '.join(sidebar_for_testing[i].split(':')[0].split('_')[:-1]).split('|'):
        if fieldname not in fieldnames.keys():
            fieldnames[fieldname] = 1
        else:
            fieldnames[fieldname] += 1

# %%
len(fieldnames.keys())
# Out:
# 386

# %%
def parse_entry(sidebar_entry):
    entry_tokens = sidebar_entry.split(':')
    return entry_tokens[0], ':'.join(entry_tokens[1:])

def parse_raw_key(raw_key):
    key_tokens = raw_key.split('_')
    
    if len(key_tokens) == 1:
        return raw_key, None
    
    if key_tokens[-1].isdigit():
        return ' '.join(key_tokens[:-1]), key_tokens[-1]
    
    return ' '.join(key_tokens), None

def parse_sidebar_dict(raw_sidebar):
    parsed_sidebar = {}
    for sidebar_entry in raw_sidebar.split('\t'):
        raw_key, value = parse_entry(sidebar_entry)
        fieldname, num = parse_raw_key(raw_key)
        
        if value == '<none>':
            continue
        
        if fieldname not in parsed_sidebar:
            parsed_sidebar[fieldname] = value
        elif value == ',' or value[0] == '\'' or (parsed_sidebar[fieldname].isdigit() and value.isdigit()):
            parsed_sidebar[fieldname] += value
        else:
            parsed_sidebar[fieldname] += ' ' + value
    
    return parsed_sidebar

def clean(value):
    value = value.replace('-lrb- ', '(')
    value = value.replace(' -rrb-', ')')
    value = value.strip()
    return value

def parse_sidebar(raw_sidebar):
    parsed_sidebar_dict = parse_sidebar_dict(raw_sidebar)
    
    sidebar_values = list(parsed_sidebar_dict.keys()) + list(parsed_sidebar_dict.values())
    sidebar_values = [clean(value) for value in sidebar_values]
    
    sidebar_str = ' --- '.join(sidebar_values)
    
    return sidebar_str

parse_sidebar(sidebar_for_testing[1])
# Out:
# 'name --- fullname --- birth date --- birth place --- height --- position --- youthyears --- youthclubs --- years --- clubs --- caps --- goals --- pcupdate --- article title --- aaron hohlbein --- aaron hohlbein --- 16 august 1985 --- middleton, wisconsin, united states --- 60 --- defender --- 2003 -- 2006 --- wisconsin badgers --- 2003 -- 2006 2006 2007 -- 2010 2010 2011 --- wisconsin badgers princeton 56ers kansas city wizards → miami fc (loan) fort lauderdale strikers --- 12431014 --- 0200 --- june 4, 2011 --- aaron hohlbein'

# %%
def parse_dataset_for_documents(csv_path, data_dir, urls_path, titles_path, num_docs):
    df = pd.DataFrame(columns=['document number', 'document', 'summary', 'headers', 'title', 'url', 'sidebar'])
    docs = []
    summaries = []
    numbers = []
    used_document_count = 0
    skipped_document_count = 0
    ordered_urls = []
    ordered_titles = []
    ordered_sidebars = []
    wiki_headers = []
    
    urls = open(urls_path, 'r').readlines()
    titles = open(titles_path, 'r').readlines()
    sidebars = open(sidebars_path, 'r').readlines()
    filenames = os.listdir(data_dir)
    num_docs = num_docs if num_docs > 0 else len(filenames)

    print(num_docs)
    for i in range(num_docs):
        filename = filenames[i]
        doc_num = int(filename.split(".")[0])
        extension = filename.split(".")[1]
        if extension != 'txt':
            continue
            
        title = titles[doc_num].replace('-lrb- ', '(').replace(' -rrb-', ')')
        lines = open(data_dir + filename).readlines()
        document = parse_document(lines)
        summary, summary_indices = parse_summary(lines)
        lower_bound, upper_bound = summary_indices
        
        headers = parse_content_headers(lines)
        
        if document != "" and summary != "":
            url = urls[int(doc_num)]
            sidebar = parse_sidebar(sidebars[doc_num])
            
            docs.append(document)
            summaries.append(summary)
            numbers.append(doc_num)
            ordered_titles.append(title[:len(title) - 1])
            ordered_urls.append(url[:len(url) - 1])
            ordered_sidebars.append(sidebar)
            wiki_headers.append(' --- '.join(headers))
            
            used_document_count += 1
        else:
            skipped_document_count += 1
                    
        total_count = used_document_count + skipped_document_count
        if (total_count) % 10000 == 0:
            print('{0} processed. {1} used. {2} skipped.'.format(total_count, used_document_count, skipped_document_count))
            
    df['document'] = docs
    df['summary'] = summaries
    df['document number'] = numbers
    df['title'] = ordered_titles
    df['url'] = ordered_urls
    df['sidebar'] = ordered_sidebars
    df['headers'] = wiki_headers
    
    df.to_csv(csv_path, index=False)
    
    return used_document_count, skipped_document_count

# %%
used_count, skipped_count = parse_dataset_for_documents(out_csv_path, data_dir, urls_path, titles_path, -1)
# Out:
# 201320
# 10000 processed. 5635 used. 4365 skipped.
# 20000 processed. 11154 used. 8846 skipped.
# 30000 processed. 16772 used. 13228 skipped.
# 40000 processed. 22344 used. 17656 skipped.
# 50000 processed. 27885 used. 22115 skipped.
# 60000 processed. 33387 used. 26613 skipped.
# 70000 processed. 38954 used. 31046 skipped.
# 80000 processed. 44631 used. 35369 skipped.
# 90000 processed. 50177 used. 39823 skipped.
# 100000 processed. 55723 used. 44277 skipped.
# 110000 processed. 61353 used. 48647 skipped.
# 120000 processed. 66959 used. 53041 skipped.
# 130000 processed. 72603 used. 57397 skipped.
# 140000 processed. 78150 used. 61850 skipped.
# 150000 processed. 83710 used. 66290 skipped.
# 160000 processed. 89251 used. 70749 skipped.
# 170000 processed. 94819 used. 75181 skipped.
# 180000 processed. 100422 used. 79578 skipped.
# 190000 processed. 106038 used. 83962 skipped.
# 200000 processed. 111574 used. 88426 skipped.

# %%
df = pd.read_csv(out_csv_path)

# %%
df
# Out:
#         document number                                           document  \
# 0                 91809  Harsha completed his ordinary level at Wesley,...
# 1                 24269  Mejía was born in Azua in the southwestern Dom...
# 2                 70462  He was drafted in the fourth round, seventy-th...
# 3                 69510  Moore was born in Wheelock in Robertson County...
# 4                 88466  McDonald was born in Kemper County near Meridi...
# 5                 31978  Flavio Boltro starts playing trumpet at 9 year...
# 6                 42093  He was born in Chadwell Heath, Essex, the son ...
# 7                 10326  Born in Hong Kong, Andrew Li received his earl...
# 8                193694  Aketxe was born in Bilbao, Biscay. Having emer...
# 9                 90040  Roswell High is a young adult book series writ...
# 10                87223  Jacinto was born in Luanda, Angola, to parents...
# 11                71634  Guillaume de Donjeon was born into the ancient...
# 12                58431  Voice of My Father, as Mehmet, 2012 (also cred...
# 13               163714  Virtuoso played in the youthsystems of Guarati...
# 14                32481  Prokurorov was born in the village of Mishino ...
# 15               136059  Bethany Charlotte Firth was born on 14 Februar...
# 16               135891  Arrillaga-Andreessen was born in Palo Alto, Ca...
# 17                54173  In 2012, Hansen became the second Australian t...
# 18                24010  Kail grew up in Alexandria, Virginia[2] and gr...
# 19                74306  Biemiller was born July 23, 1906 in Sandusky, ...
# 20                21339  Maguire was born in Gadsden, Alabama, on Augus...
# 21                58580  Nelson was born on November 10, 1974,[1] as Ja...
# 22                75516  She was only eight when she made her first app...
# 23               106883  Mara Marini was born in Winnipeg, Manitoba,[1]...
# 24               114017  Everett earned his BA in English from Chapman ...
# 25                11018  Kay Fisker was born on 14 February 1893 in the...
# 26                58330  Lakland 44-64 ( P bass with a Jazz neck) with ...
# 27                24770  Born in Silla, Province of Valencia, López gra...
# 28                28111  M.H.Siddiqi's ancestors migrated to India duri...
# 29               139497  Barcroft was born Howard Harold Ravenscroft[4]...
# ...                 ...                                                ...
# 112291            49380  Prince Philippe became the Prince Royal, heir ...
# 112292           172666  Born in Brighton, England, Gandey grew up unde...
# 112293           128188  Kuhn was born in New York City and grew up in ...
# 112294           166607  Karl Gallwitz was born in Sigmaringen, the Ger...
# 112295            54960  Kisielewski-Tomaszewski: Play Favourite Melodi...
# 112296           164249  Born in Gdańsk, Poland, Frackowiak was sixteen...
# 112297            51617  Bradshaw was born at Windsor Bridge, Pendleton...
# 112298           145928  Cook was born in Boston, Massachusetts. In 190...
# 112299           167131  Kourouma began his career with Jeunesse Club d...
# 112300            92650  A Muslim woman of Pakistani origin, she was ra...
# 112301            91624  Schröer was born on 12 February 1918 in Mülhei...
# 112302            28642  In 1955 he graduated from the National Institu...
# 112303           134573  Norman Marjoribanks was born in India on 16 Oc...
# 112304            25198  A reputed former leader of the Bamboo Union cr...
# 112305           190381  Nima Aziminejad is the son of Jamshid Aziminej...
# 112306           179286  Before Ang started playing in the S.League, he...
# 112307           155695  He was born John Greenhalgh Hylton in Great Le...
# 112308           173349  He was editor of Combustion and Flame from 198...
# 112309           127162  Pierre-Michel Lasogga grew up as the son of pl...
# 112310           133710  Formed by childhood friends Koroshec and Kelly...
# 112311            22250  Walton enjoyed a lengthy competitive career, w...
# 112312           149819  Mushet was born on 2 October 1772 in Dalkeith ...
# 112313            19231  Martinez was born in Los Angeles, California. ...
# 112314           192338  Magani was the Shkumbini top league goalscorer...
# 112315           196358  Born in Brunswick (in modern-day Maine, then a...
# 112316           119980  Molteno was born in Cape Town, then part of th...
# 112317           131036  The core of Hello was founded around 1969, ori...
# 112318            64332  On 7 September 2011, Snurnitsyn was killed, wh...
# 112319           124878  After starting his career at local side Panama...
# 112320           194683  Ochiai was born in the town of Wakami in Akita...
#
#                                                   summary  \
# 0       Harsha Purasinghe is a serial entrepreneur who...
# 1       Jenrry Manuel Mejía (Spanish pronunciation: [ˈ...
# 2       Darby Joseph Hendrickson (born August 28, 1972...
# 3       William Tyler Moore, Sr., known as W. T. "Bill...
# 4       William Jesse McDonald, known as Captain Bill ...
# 5       Flavio Boltro (born May 5, 1961) is an Italian...
# 6       Alan Derek Piggott MBE (born 27 December 1922)...
# 7       This is a Chinese name; the family name is Li....
# 8       Isaac Aketxe Barrutia (Spanish pronunciation: ...
# 9       Melinda Metz is an American author of young ad...
# 10      António Jacinto, full name António Jacinto do ...
# 11      Saint Guillaume de Donjeon (c. 19 October 1150...
# 12      Zeynel Doğan, (pronounced [zejnel doɣɑn]), *Oc...
# 13      Ricardo Magno Virtuoso Guarà (born March 1, 19...
# 14      Alexey Alexeyevich Prokurorov (Russian: Алексе...
# 15      Bethany Charlotte Firth, MBE (born 14 February...
# 16      She is the founder and president of the Laura ...
# 17      Adam Hansen (born 11 May 1981 in Southport, Qu...
# 18      Thomas Kail (born January 20, 1978) is an Amer...
# 19      Andrew John Biemiller (July 23, 1906 – April 3...
# 20      Bassett Maguire (August 4, 1904 – February 6, ...
# 21      Jason Albert Nelson (born November 10, 1974) i...
# 22      Bertha Belmore (1882–1953) was a British stage...
# 23      Mara Marini is a Canadian actress best known f...
# 24      Justin Everett[2] (Born August 5, 1971) is an ...
# 25      Kay Otto Fisker, Hon. FAIA (14 February 1893 –...
# 26      Dan Maines (born March 10, 1971) is the bassis...
# 27      * Senior club appearances and goals counted fo...
# 28      Manzoor Ul Haq Siddiqi (Urdu:منطورالحق صدیقی; ...
# 29      Roy Barcroft (September 7, 1902 – November 28,...
# ...                                                   ...
# 112291  Prince Philippe of Orléans, Count of Paris (Lo...
# 112292  Thomas Gandey is an English electronic music p...
# 112293  Eric Kuhn is an American media executive. Desc...
# 112294  Leutnant Karl Gallwitz was a World War I flyin...
# 112295  Marek Tomaszewski (born 20 November 1943 in Kr...
# 112296  Magdalena Frąckowiak (Polish: [frɔ̃nt͡sˈkɔviak...
# 112297  George Bradshaw (29 July 1800 – 6 September 18...
# 112298  Warren Cook (May 23, 1878 – May 2, 1939) was a...
# 112299  Mohamed Lamine Kourouma (born January 1, 1987 ...
# 112300  Zarqa Nawaz (born 1968 in Liverpool, England) ...
# 112301  Werner Schröer[Note 1] (12 February 1918 – 10 ...
# 112302  Manole Marcus (8 January 1928 – 12 October 199...
# 112303  Sir Norman Edward Marjoribanks KCIE, CSI (16 O...
# 112304  Chang An-lo (Chinese: 張安樂; pinyin: Zhāng Ānlè)...
# 112305  Nima Aziminejad ( Persian: نیما عظیمی‌نژاد‎), ...
# 112306  Ignatius Ang Yu Heng (born 11 November 1992) i...
# 112307  Jack Hylton (born John Greenhalgh Hilton,[1] 2...
# 112308  Kenneth Noel Corbett Bray FRS is Emeritus Prof...
# 112309  Pierre-Michel Lasogga (born 15 December 1991) ...
# 112310  The Autumns were an American indie rock[2] ban...
# 112311  Caz Walton OBE (born Carol Bryant; 1 February ...
# 112312  David Mushet (2 October 1772 – 7 June 1847) wa...
# 112313  Roberta H. Martinez (born June 18, 1952) is an...
# 112314  Artur Gugash Magani (born 8 July 1994) is an A...
# 112315  Robert Pinckney Dunlap (August 17, 1794 – Octo...
# 112316  Vice Admiral Vincent Barkly Molteno CB (30 Apr...
# 112317  Hello is an English teen appeal glam rock band...
# 112318  Pavel Sergeyevich Snurnitsyn (occasionally spe...
# 112319  This name uses Spanish naming customs: the fir...
# 112320  Hiromitsu Ochiai (落合 博満 Ochiai Hiromitsu, born...
#
#                                                   headers  \
# 0       Background --- Awards & Recognitions --- Publi...
# 1       Early life --- Professional career --- Minor l...
# 2       Playing career --- Career statistics --- Regul...
# 3       Background --- Powerful legislator --- Promoti...
# 4       Early years, family, education --- Law enforce...
# 5       Career --- The Italian years --- The French ye...
# 6       Early years --- Royal Air Force --- Gliding ca...
# 7       Early life and education --- Legal career --- ...
# 8                       Football career --- Personal life
# 9       Works --- Roswell High --- Fingerprints --- Pa...
# 10                Biography --- Selected poems --- Quotes
# 11                                     Life --- Sainthood
# 12                                 Filmography --- Awards
# 13      Career --- Club --- International --- Futsal -...
# 14      Career --- World Cup results --- Individual po...
# 15                      Personal life --- Swimming career
# 16      Early life and education --- Career --- Honors...
# 17      Career --- Career achievements --- Major resul...
# 18      Personal life --- Career --- Filmography --- A...
# 19      Background --- Public office --- Assembly --- ...
# 20                              Life --- Awards --- Works
# 21      Early life --- Music career --- Personal life ...
# 22                  Early career --- Selected filmography
# 23                  Early life --- Career --- Filmography
# 24      Education --- Elections --- 71st General Assem...
# 25      Education and career --- Academia --- Selected...
# 26               Equipment --- Basses --- Amps --- Pedals
# 27      Playing career --- Coaching career --- Manager...
# 28      Background --- Early life --- Political career...
# 29      Background --- Career --- Personal life --- De...
# ...                                                   ...
# 112291  Early life --- Marriage and issue --- Restorat...
# 112292  Early life and career --- 2004 - 2014: Cagedba...
# 112293  Early life and education --- Career --- Boards...
# 112294  Early life --- Aerial service --- Postwar --- ...
# 112295  Discography --- With Marek and Wacek --- Long ...
# 112296                              Early life --- Career
# 112297  Biography --- Bradshaw's railway guides --- Gr...
# 112298                 Biography --- Selected filmography
# 112299                    Career --- International career
# 112300  Biography --- Short films --- Screenplays --- ...
# 112301  Early life and career --- World War II --- Nor...
# 112302  Studies --- Professional activity --- Filmogra...
# 112303  Early life --- In the Civil Service --- Commis...
# 112304  Work with the Triad --- Political career --- N...
# 112305  Biography --- Activities --- Theatre music com...
# 112306  Youth Career --- Career --- Young Lions --- Ho...
# 112307  Early life and career --- 1920s and '30s --- 1...
# 112308                                     Life --- Works
# 112309  Career --- Early years --- First experiences i...
# 112310                            History --- Discography
# 112311  Sporting career --- Paralympics --- Awards and...
# 112312  Early life --- Career in Scotland --- Career i...
# 112313  Early life and education --- Work experience -...
# 112314  Club career --- Shkumbini Peqin --- Teuta Durr...
# 112315                     Biography --- Death and burial
# 112316  Early life --- World War I --- Family life ---...
# 112317  Career --- Discography --- Albums --- Singles ...
# 112318                                              Death
# 112319    Club career --- International career --- Honors
# 112320  Biography --- Awards and accomplishments --- C...
#
#                                       title  \
# 0                         harsha purasinghe
# 1                              jenrry mejía
# 2                         darby hendrickson
# 3       william t. moore (texas politician)
# 4              bill mcdonald (texas ranger)
# 5                             flavio boltro
# 6                             derek piggott
# 7                                 andrew li
# 8                              isaac aketxe
# 9                              melinda metz
# 10                          antónio jacinto
# 11                       william of donjeon
# 12                             zeynel doğan
# 13                         ricardo virtuoso
# 14                        alexey prokurorov
# 15                            bethany firth
# 16               laura arrillaga-andreessen
# 17                              adam hansen
# 18                              thomas kail
# 19                         andrew biemiller
# 20                          bassett maguire
# 21                  jason nelson (musician)
# 22                           bertha belmore
# 23                              mara marini
# 24                           justin everett
# 25                               kay fisker
# 26                               dan maines
# 27           francisco josé lópez fernández
# 28                   manzoor ul haq siddiqi
# 29                             roy barcroft
# ...                                     ...
# 112291     prince philippe , count of paris
# 112292                        thomas gandey
# 112293                            eric kuhn
# 112294                        karl gallwitz
# 112295                    marek tomaszewski
# 112296                 magdalena frackowiak
# 112297                      george bradshaw
# 112298                          warren cook
# 112299                      lamine kourouma
# 112300                          zarqa nawaz
# 112301                       werner schröer
# 112302                        manole marcus
# 112303                  norman marjoribanks
# 112304                          chang an-lo
# 112305                      nima aziminejad
# 112306                         ignatius ang
# 112307                          jack hylton
# 112308                         kenneth bray
# 112309                pierre-michel lasogga
# 112310                          the autumns
# 112311                           caz walton
# 112312                         david mushet
# 112313                  roberta h. martinez
# 112314                         artur magani
# 112315                     robert p. dunlap
# 112316               vincent barkly molteno
# 112317                         hello (band)
# 112318                     pavel snurnitsyn
# 112319                   juan de dios pérez
# 112320                     hiromitsu ochiai
#
#                                                       url  \
# 0       https://en.wikipedia.org/wiki/index.php?curid=...
# 1       https://en.wikipedia.org/wiki/index.php?curid=...
# 2       https://en.wikipedia.org/wiki/index.php?curid=...
# 3       https://en.wikipedia.org/wiki/index.php?curid=...
# 4       https://en.wikipedia.org/wiki/index.php?curid=...
# 5       https://en.wikipedia.org/wiki/index.php?curid=...
# 6       https://en.wikipedia.org/wiki/index.php?curid=...
# 7       https://en.wikipedia.org/wiki/index.php?curid=...
# 8       https://en.wikipedia.org/wiki/index.php?curid=...
# 9       https://en.wikipedia.org/wiki/index.php?curid=...
# 10      https://en.wikipedia.org/wiki/index.php?curid=...
# 11      https://en.wikipedia.org/wiki/index.php?curid=...
# 12      https://en.wikipedia.org/wiki/index.php?curid=...
# 13      https://en.wikipedia.org/wiki/index.php?curid=...
# 14      https://en.wikipedia.org/wiki/index.php?curid=...
# 15      https://en.wikipedia.org/wiki/index.php?curid=...
# 16      https://en.wikipedia.org/wiki/index.php?curid=...
# 17      https://en.wikipedia.org/wiki/index.php?curid=...
# 18      https://en.wikipedia.org/wiki/index.php?curid=...
# 19      https://en.wikipedia.org/wiki/index.php?curid=...
# 20      https://en.wikipedia.org/wiki/index.php?curid=...
# 21      https://en.wikipedia.org/wiki/index.php?curid=...
# 22      https://en.wikipedia.org/wiki/index.php?curid=...
# 23      https://en.wikipedia.org/wiki/index.php?curid=...
# 24      https://en.wikipedia.org/wiki/index.php?curid=...
# 25      https://en.wikipedia.org/wiki/index.php?curid=...
# 26      https://en.wikipedia.org/wiki/index.php?curid=...
# 27      https://en.wikipedia.org/wiki/index.php?curid=...
# 28      https://en.wikipedia.org/wiki/index.php?curid=...
# 29      https://en.wikipedia.org/wiki/index.php?curid=...
# ...                                                   ...
# 112291  https://en.wikipedia.org/wiki/index.php?curid=...
# 112292  https://en.wikipedia.org/wiki/index.php?curid=...
# 112293  https://en.wikipedia.org/wiki/index.php?curid=...
# 112294  https://en.wikipedia.org/wiki/index.php?curid=...
# 112295  https://en.wikipedia.org/wiki/index.php?curid=...
# 112296  https://en.wikipedia.org/wiki/index.php?curid=...
# 112297  https://en.wikipedia.org/wiki/index.php?curid=...
# 112298  https://en.wikipedia.org/wiki/index.php?curid=...
# 112299  https://en.wikipedia.org/wiki/index.php?curid=...
# 112300  https://en.wikipedia.org/wiki/index.php?curid=...
# 112301  https://en.wikipedia.org/wiki/index.php?curid=...
# 112302  https://en.wikipedia.org/wiki/index.php?curid=...
# 112303  https://en.wikipedia.org/wiki/index.php?curid=...
# 112304  https://en.wikipedia.org/wiki/index.php?curid=...
# 112305  https://en.wikipedia.org/wiki/index.php?curid=...
# 112306  https://en.wikipedia.org/wiki/index.php?curid=...
# 112307  https://en.wikipedia.org/wiki/index.php?curid=...
# 112308  https://en.wikipedia.org/wiki/index.php?curid=...
# 112309  https://en.wikipedia.org/wiki/index.php?curid=...
# 112310  https://en.wikipedia.org/wiki/index.php?curid=...
# 112311  https://en.wikipedia.org/wiki/index.php?curid=...
# 112312  https://en.wikipedia.org/wiki/index.php?curid=...
# 112313  https://en.wikipedia.org/wiki/index.php?curid=...
# 112314  https://en.wikipedia.org/wiki/index.php?curid=...
# 112315  https://en.wikipedia.org/wiki/index.php?curid=...
# 112316  https://en.wikipedia.org/wiki/index.php?curid=...
# 112317  https://en.wikipedia.org/wiki/index.php?curid=...
# 112318  https://en.wikipedia.org/wiki/index.php?curid=...
# 112319  https://en.wikipedia.org/wiki/index.php?curid=...
# 112320  https://en.wikipedia.org/wiki/index.php?curid=...
#
#                                                   sidebar
# 0       name --- nationality --- occupation --- birth ...
# 1       name --- image --- width --- caption --- team ...
# 2       position --- shoots --- height ft --- height i...
# 3       name --- nationality --- state senate --- dist...
# 4       name --- image --- image size --- caption --- ...
# 5       name --- image --- caption --- background --- ...
# 6       name --- honorific suffix --- image --- captio...
# 7       name --- order --- office --- term start --- t...
# 8       name --- fullname --- birth date --- birth pla...
# 9       name --- birth place --- genre --- occupation ...
# 10      name --- birth name --- birth date --- birth p...
# 11      name --- birth date --- death date --- feast d...
# 12      name --- alma mater --- occupation --- yearsac...
# 13      name --- fullname --- birth date --- birth pla...
# 14      image --- caption --- article title --- vladim...
# 15      name --- nationality --- sport --- strokes ---...
# 16      name --- image --- image size --- education --...
# 17      name --- image --- caption --- fullname --- ni...
# 18      name --- birth date --- birth place --- nation...
# 19      name --- state --- district --- term start ---...
# 20      name --- birth date --- birth place --- death ...
# 21      name --- background --- birth name --- birth d...
# 22      name --- image --- caption --- birthname --- b...
# 23      name --- image --- birth place --- alma mater ...
# 24      name --- image --- state house --- district --...
# 25      name --- image --- image size --- nationality ...
# 26      name --- image --- caption --- background --- ...
# 27      name --- image --- image size --- fullname ---...
# 28      name --- image --- birth date --- birth place ...
# 29      name --- birth name --- birth date --- birth p...
# ...                                                   ...
# 112291  name --- title --- image --- succession --- re...
# 112292  name --- image --- alt --- caption --- backgro...
# 112293  name --- birth name --- birth date --- birth p...
# 112294  name --- birth date --- death date --- birth p...
# 112295  name --- background --- birth name --- birth d...
# 112296  name --- image --- caption --- birth name --- ...
# 112297  name --- image --- image size --- caption --- ...
# 112298  name --- image --- caption --- birth date --- ...
# 112299  name --- fullname --- birth date --- birth pla...
# 112300  name --- image size --- birth date --- birth p...
# 112301  name --- birth date --- death date --- birth p...
# 112302  name --- birth date --- birth place --- death ...
# 112303  name --- imagesize --- order --- term start --...
# 112304  name --- image --- image size --- caption --- ...
# 112305  name --- birth name --- birth date --- backgro...
# 112306  name --- fullname --- birth date --- birth pla...
# 112307  name --- image --- background --- birth name -...
# 112308  birth name --- article title --- kenneth noel ...
# 112309  name --- image --- caption --- fullname --- bi...
# 112310  name --- background --- origin --- genre --- y...
# 112311  name --- birth name --- birth date --- sport -...
# 112312  name --- image --- birth date --- birth place ...
# 112313  name --- birth date --- birth place --- occupa...
# 112314  name --- fullname --- birth date --- birth pla...
# 112315  name --- image --- caption --- order --- term ...
# 112316  name --- image --- caption --- birth date --- ...
# 112317  background --- origin --- genre --- years acti...
# 112318  name --- image size --- former teams --- posit...
# 112319  name --- fullname --- birth date --- birth pla...
# 112320  name --- image --- image size --- birth date -...
#
# [112321 rows x 7 columns]

# %%
print(len(df['sidebar']))
df['sidebar'].isnull().sum()
# Out:
# 112321
# 0
